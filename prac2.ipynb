# %% [markdown]
# <a href="https://colab.research.google.com/github/Jiya003/Machine-Learning-Practice/blob/main/prac2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: house_data.csv with features like Area, Bedrooms, Location, Price
#
# MULTIPLE LINEAR REGRESSION
#
# Task:
#
#     Build an SLR model to predict Price based on Area
#
#     Train/test split
#
#     Predict on test data
#
#     Save predictions to house_price_predictions.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

df=pd.read_csv('Housing.csv')

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df['mainroad'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['guestroom'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['prefarea'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df=pd.get_dummies(df,columns=['mainroad','guestroom','basement','prefarea','furnishingstatus','airconditioning','hotwaterheating'],drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price                            545 non-null    int64
#  1   area                             545 non-null    int64
#  2   bedrooms                         545 non-null    int64
#  3   bathrooms                        545 non-null    int64
#  4   stories                          545 non-null    int64
#  5   parking                          545 non-null    int64
#  6   mainroad_yes                     545 non-null    bool
#  7   guestroom_yes                    545 non-null    bool
#  8   basement_yes                     545 non-null    bool
#  9   prefarea_yes                     545 non-null    bool
#  10  furnishingstatus_semi-furnished  545 non-null    bool
#  11  furnishingstatus_unfurnished     545 non-null    bool
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  ...  furnishingstatus_unfurnished  airconditioning_yes  hotwaterheating_yes
# 0  13300000  7420         4  ...                         False                 True                False
# 1  12250000  8960         4  ...                         False                 True                False
# 2  12250000  9960         3  ...                         False                False                False
# 3  12215000  7500         4  ...                         False                 True                False
# 4  11410000  7420         4  ...                         False                 True                False
#
# [5 rows x 14 columns]

# %%
X=df.drop(columns=['price'])
Y=df['price']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
mae=mean_absolute_error(Y_test,Y_pred)
mse=mean_squared_error(Y_test,Y_pred)
rmse=np.sqrt(mse)
r2=r2_score(Y_test,Y_pred)

print(f"The mae is: {mae:.2f}")
print(f"The mse is: {mse:.2f}")
print(f"The rmse is: {rmse:.2f}")
print(f"The r2 score is: {r2:.2f}")
# Out:
# The mae is: 970043.40
# The mse is: 1754318687330.66
# The rmse is: 1324506.96
# The r2 score is: 0.65

# %%
output_df=pd.DataFrame({
    'Actual Price':Y_test.values,
    'Prediction Price':Y_pred
})

output_df.to_csv("output.csv",index=False,sep=',')
